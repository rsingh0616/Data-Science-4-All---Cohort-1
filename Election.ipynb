# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np

# %%
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)

# %%
import os
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'DS4A Team 53-0add780445ac.json'

# %%
from google.cloud import bigquery

# %%
bigquery_client = bigquery.Client()

# %% [markdown]
# ## Combining all years of Operations Expenses

# %%
query_oppexp_a = """
SELECT cmte_id, transaction_amt, transaction_dt, category, state FROM `bigquery-public-data.fec.oppexp04` 
"""

query_job_oppexp_a = bigquery_client.query(query_oppexp_a)
df_oppexp_a = query_job_oppexp_a.to_dataframe()

# %%
df_oppexp_a['file_name_year'] = 2004
df_oppexp_a['transaction_dt'] = pd.to_datetime(df_oppexp_a['transaction_dt'], format= '%Y-%m-%d', errors = 'coerce')
df_oppexp_a['year'] = pd.to_datetime(df_oppexp_a['transaction_dt']).dt.to_period('Y')
df_oppexp_a['month-year'] = pd.to_datetime(df_oppexp_a['transaction_dt']).dt.to_period('M')

df_oppexp_a = df_oppexp_a.loc[df_oppexp_a['state'].isin(["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
                                         "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", 
                                         "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", 
                                         "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", 
                                         "UT", "VT", "VA", "WA", "WV", "WI", "WY"])]

df_oppexp_a = df_oppexp_a.groupby(['state', 'cmte_id', 'category', 'month-year', 'file_name_year']).sum('transaction_amt').reset_index()

# %%
df_oppexp_a.head()
# Out:
#   state    cmte_id category month-year  file_name_year  transaction_amt
# 0    AK  C00009936      002    2004-07            2004           223.78
# 1    AK  C00011114      002    2004-06            2004          1506.46
# 2    AK  C00011114      002    2004-07            2004          4160.59
# 3    AK  C00011114      002    2004-08            2004          1543.66
# 4    AK  C00011114      002    2004-09            2004           223.77

# %%
query_oppexp_b = """
SELECT cmte_id, transaction_amt, transaction_dt, category, state FROM `bigquery-public-data.fec.oppexp06` 
"""
query_job_oppexp_b = bigquery_client.query(query_oppexp_b)
df_oppexp_b = query_job_oppexp_b.to_dataframe()

# %%
df_oppexp_b['file_name_year'] = 2006
df_oppexp_b['transaction_dt'] = pd.to_datetime(df_oppexp_b['transaction_dt'], format= '%Y-%m-%d', errors = 'coerce')
df_oppexp_b['year'] = pd.to_datetime(df_oppexp_b['transaction_dt']).dt.to_period('Y')
df_oppexp_b['month-year'] = pd.to_datetime(df_oppexp_b['transaction_dt']).dt.to_period('M')

df_oppexp_b = df_oppexp_b.loc[df_oppexp_b['state'].isin(["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
                                         "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", 
                                         "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", 
                                         "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", 
                                         "UT", "VT", "VA", "WA", "WV", "WI", "WY"])]

df_oppexp_b = df_oppexp_b.groupby(['state', 'cmte_id', 'category', 'month-year', 'file_name_year']).sum('transaction_amt').reset_index()

# %%
df_oppexp_b.head()
# Out:
#   state    cmte_id category month-year  file_name_year  transaction_amt
# 0    AK  C00003251      003    2005-07            2006            460.0
# 1    AK  C00007880      003    2006-05            2006           4162.0
# 2    AK  C00012229      005    2005-01            2006            500.0
# 3    AK  C00039164      001    2005-11            2006            325.0
# 4    AK  C00039164      001    2005-12            2006            540.0

# %%
query_oppexp_c = """
SELECT cmte_id, transaction_amt, transaction_dt, category, state FROM `bigquery-public-data.fec.oppexp08` 
"""
query_job_oppexp_c = bigquery_client.query(query_oppexp_c)
df_oppexp_c = query_job_oppexp_c.to_dataframe()

# %%
df_oppexp_c['file_name_year'] = 2008
df_oppexp_c['transaction_dt'] = pd.to_datetime(df_oppexp_c['transaction_dt'], format= '%Y-%m-%d', errors = 'coerce')
df_oppexp_c['year'] = pd.to_datetime(df_oppexp_c['transaction_dt']).dt.to_period('Y')
df_oppexp_c['month-year'] = pd.to_datetime(df_oppexp_c['transaction_dt']).dt.to_period('M')

df_oppexp_c = df_oppexp_c.loc[df_oppexp_c['state'].isin(["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
                                         "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", 
                                         "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", 
                                         "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", 
                                         "UT", "VT", "VA", "WA", "WV", "WI", "WY"])]

df_oppexp_c = df_oppexp_c.groupby(['state', 'cmte_id', 'category', 'month-year', 'file_name_year']).sum('transaction_amt').reset_index()

# %%
df_oppexp_c.head()
# Out:
#   state    cmte_id category month-year  file_name_year  transaction_amt
# 0    AK  C00000935      002    2008-08            2008           177.05
# 1    AK  C00000935      002    2008-09            2008            32.95
# 2    AK  C00000935      002    2008-11            2008           620.00
# 3    AK  C00000935      005    2007-09            2008          4000.00
# 4    AK  C00003251      003    2007-07            2008           260.00

# %%
query_oppexp_d = """
SELECT cmte_id, transaction_amt, transaction_dt, category, state FROM `bigquery-public-data.fec.oppexp10` 
"""
query_job_oppexp_d = bigquery_client.query(query_oppexp_d)
df_oppexp_d = query_job_oppexp_d.to_dataframe()

# %%
df_oppexp_d['file_name_year'] = 2010
df_oppexp_d['transaction_dt'] = pd.to_datetime(df_oppexp_d['transaction_dt'], format= '%Y-%m-%d', errors = 'coerce')
df_oppexp_d['year'] = pd.to_datetime(df_oppexp_d['transaction_dt']).dt.to_period('Y')
df_oppexp_d['month-year'] = pd.to_datetime(df_oppexp_d['transaction_dt']).dt.to_period('M')

df_oppexp_d = df_oppexp_d.loc[df_oppexp_d['state'].isin(["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
                                         "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", 
                                         "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", 
                                         "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", 
                                         "UT", "VT", "VA", "WA", "WV", "WI", "WY"])]

df_oppexp_d = df_oppexp_d.groupby(['state', 'cmte_id', 'category', 'month-year', 'file_name_year']).sum('transaction_amt').reset_index()

# %%
df_oppexp_d.head()
# Out:
#   state    cmte_id category month-year  file_name_year  transaction_amt
# 0    AK  C00003251      003    2009-07            2010           167.00
# 1    AK  C00007922      012    2009-02            2010          3000.00
# 2    AK  C00028316      001    2010-04            2010           513.08
# 3    AK  C00028316      001    2010-05            2010           209.14
# 4    AK  C00028316      001    2010-06            2010          5384.22

# %%
query_oppexp_e = """
SELECT cmte_id, transaction_amt, transaction_dt, category, state FROM `bigquery-public-data.fec.oppexp12` 
"""
query_job_oppexp_e = bigquery_client.query(query_oppexp_e)
df_oppexp_e = query_job_oppexp_e.to_dataframe()

# %%
df_oppexp_e['file_name_year'] = 2012
df_oppexp_e['transaction_dt'] = pd.to_datetime(df_oppexp_e['transaction_dt'], format= '%Y-%m-%d', errors = 'coerce')
df_oppexp_e['year'] = pd.to_datetime(df_oppexp_e['transaction_dt']).dt.to_period('Y')
df_oppexp_e['month-year'] = pd.to_datetime(df_oppexp_e['transaction_dt']).dt.to_period('M')

df_oppexp_e = df_oppexp_e.loc[df_oppexp_e['state'].isin(["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
                                         "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", 
                                         "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", 
                                         "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", 
                                         "UT", "VT", "VA", "WA", "WV", "WI", "WY"])]

df_oppexp_e = df_oppexp_e.groupby(['state', 'cmte_id', 'category', 'month-year', 'file_name_year']).sum('transaction_amt').reset_index()

# %%
df_oppexp_e.head()
# Out:
#   state    cmte_id category month-year  file_name_year  transaction_amt
# 0    AK  C00001461             2011-05            2012            49.30
# 1    AK  C00001461             2011-06            2012            49.32
# 2    AK  C00001461             2011-07            2012           105.67
# 3    AK  C00001461             2011-08            2012           136.66
# 4    AK  C00001461             2011-09            2012            48.46

# %%
query_oppexp_f = """
SELECT cmte_id, transaction_amt, transaction_dt, category, state FROM `bigquery-public-data.fec.oppexp14` 
"""
query_job_oppexp_f = bigquery_client.query(query_oppexp_f)
df_oppexp_f = query_job_oppexp_f.to_dataframe()

# %%
df_oppexp_f['file_name_year'] = 2014
df_oppexp_f['transaction_dt'] = pd.to_datetime(df_oppexp_f['transaction_dt'], format= '%Y-%m-%d', errors = 'coerce')
df_oppexp_f['year'] = pd.to_datetime(df_oppexp_f['transaction_dt']).dt.to_period('Y')
df_oppexp_f['month-year'] = pd.to_datetime(df_oppexp_f['transaction_dt']).dt.to_period('M')

df_oppexp_f = df_oppexp_f.loc[df_oppexp_f['state'].isin(["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
                                         "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", 
                                         "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", 
                                         "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", 
                                         "UT", "VT", "VA", "WA", "WV", "WI", "WY"])]

df_oppexp_f = df_oppexp_f.groupby(['state', 'cmte_id', 'category', 'month-year', 'file_name_year']).sum('transaction_amt').reset_index()

# %%
df_oppexp_f.head()
# Out:
#   state    cmte_id category month-year  file_name_year  transaction_amt
# 0    AK  C00000935      002    2014-04            2014           243.50
# 1    AK  C00000935      002    2014-06            2014           109.50
# 2    AK  C00003418             2013-04            2014           244.16
# 3    AK  C00003418             2013-11            2014          1590.00
# 4    AK  C00003418             2013-12            2014           795.00

# %%
query_oppexp_g = """
SELECT cmte_id, transaction_amt, transaction_dt, category, state FROM `bigquery-public-data.fec.oppexp16` 
"""
query_job_oppexp_g = bigquery_client.query(query_oppexp_g)
df_oppexp_g = query_job_oppexp_g.to_dataframe()
# Out:
# /usr/local/lib/python3.8/site-packages/google/cloud/bigquery/client.py:440: UserWarning: Cannot create BigQuery Storage client, the dependency google-cloud-bigquery-storage is not installed.
#   warnings.warn(

# %%
df_oppexp_g['file_name_year'] = 2016
df_oppexp_g['transaction_dt'] = pd.to_datetime(df_oppexp_g['transaction_dt'], format= '%Y-%m-%d', errors = 'coerce')
df_oppexp_g['year'] = pd.to_datetime(df_oppexp_g['transaction_dt']).dt.to_period('Y')
df_oppexp_g['month-year'] = pd.to_datetime(df_oppexp_g['transaction_dt']).dt.to_period('M')

df_oppexp_g = df_oppexp_g.loc[df_oppexp_g['state'].isin(["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
                                         "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", 
                                         "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", 
                                         "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", 
                                         "UT", "VT", "VA", "WA", "WV", "WI", "WY"])]

df_oppexp_g = df_oppexp_g.groupby(['state', 'cmte_id', 'category', 'month-year', 'file_name_year']).sum('transaction_amt').reset_index()

# %%
df_oppexp_g.head()
# Out:
#   state    cmte_id category month-year  file_name_year  transaction_amt
# 0    AK  C00000935      002    2016-01            2016            21.89
# 1    AK  C00003251      003    2015-07            2016           200.00
# 2    AK  C00003251      003    2016-07            2016            15.00
# 3    AK  C00011114      002    2016-09            2016          6893.40
# 4    AK  C00012229      001    2015-05            2016           427.78

# %%
query_oppexp_h = """
SELECT cmte_id, transaction_amt, transaction_dt, category, state FROM `bigquery-public-data.fec.oppexp18` 
"""
query_job_oppexp_h = bigquery_client.query(query_oppexp_h)
df_oppexp_h = query_job_oppexp_h.to_dataframe()

# %%
df_oppexp_h['file_name_year'] = 2018
df_oppexp_h['transaction_dt'] = pd.to_datetime(df_oppexp_h['transaction_dt'], format= '%Y-%m-%d', errors = 'coerce')
df_oppexp_h['year'] = pd.to_datetime(df_oppexp_h['transaction_dt']).dt.to_period('Y')
df_oppexp_h['month-year'] = pd.to_datetime(df_oppexp_h['transaction_dt']).dt.to_period('M')

df_oppexp_h = df_oppexp_h.loc[df_oppexp_h['state'].isin(["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
                                         "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", 
                                         "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", 
                                         "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", 
                                         "UT", "VT", "VA", "WA", "WV", "WI", "WY"])]

df_oppexp_h = df_oppexp_h.groupby(['state', 'cmte_id', 'category', 'month-year', 'file_name_year']).sum('transaction_amt').reset_index()

# %%
df_oppexp_h.head()
# Out:
#   state    cmte_id category month-year  file_name_year  transaction_amt
# 0    AK  C00345199      003    2018-08            2018          3688.25
# 1    AK  C00346312      001    2018-12            2018           275.55
# 2    AK  C00393041      011    2017-09            2018          1000.00
# 3    AK  C00438291      001    2018-11            2018           446.58
# 4    AK  C00461806      001    2018-11            2018         12500.00

# %% [markdown]
# ## Concatenate files above each other

# %%
ab= pd.concat([df_oppexp_a, df_oppexp_b], axis=0)

# %%
abc= pd.concat([ab, df_oppexp_c], axis=0)

# %%
abcd= pd.concat([abc, df_oppexp_d], axis=0)

# %%
abcde= pd.concat([abcd, df_oppexp_e], axis=0)

# %%
abcdef= pd.concat([abcde, df_oppexp_f], axis=0)

# %%
abcdefg= pd.concat([abcdef, df_oppexp_g], axis=0)

# %%
abcdefgh= pd.concat([abcdefg, df_oppexp_h], axis=0)

# %%
abcdefgh['file_name_year']= abcdefgh['file_name_year'].astype(str)

# %%
abcdefgh.head()
# Out:
#   state    cmte_id category month-year file_name_year  transaction_amt
# 0    AK  C00009936      002    2004-07           2004           223.78
# 1    AK  C00011114      002    2004-06           2004          1506.46
# 2    AK  C00011114      002    2004-07           2004          4160.59
# 3    AK  C00011114      002    2004-08           2004          1543.66
# 4    AK  C00011114      002    2004-09           2004           223.77

# %%
abcdefgh['year'] = abcdefgh['month-year'].dt.to_timestamp('s').dt.strftime('%Y')
abcdefgh['month-year'] = abcdefgh['month-year'].dt.to_timestamp('s').dt.strftime('%Y-%m')

# %%
abcdefgh.head()
# Out:
#   state    cmte_id category month-year file_name_year  transaction_amt  year
# 0    AK  C00009936      002    2004-07           2004           223.78  2004
# 1    AK  C00011114      002    2004-06           2004          1506.46  2004
# 2    AK  C00011114      002    2004-07           2004          4160.59  2004
# 3    AK  C00011114      002    2004-08           2004          1543.66  2004
# 4    AK  C00011114      002    2004-09           2004           223.77  2004

# %%
abcdefgh.to_csv("final_oppex.csv")

# %%
abcdefgh.nunique()
# Out:
# state                  51
# cmte_id             15309
# category              205
# month-year            257
# file_name_year          8
# transaction_amt    502642
# year                   35
# dtype: int64

# %%
abcdefgh.dtypes
# Out:
# state               object
# cmte_id             object
# category            object
# month-year          object
# file_name_year      object
# transaction_amt    float64
# year                object
# dtype: object

# %%
abcdefgh.isna().sum()
# Out:
# state              0
# cmte_id            0
# category           0
# month-year         0
# file_name_year     0
# transaction_amt    0
# year               0
# dtype: int64

# %%
abcdefgh.shape
# Out:
# (1223244, 7)

# %% [markdown]
# Details of disbursement category here https://www.fec.gov/campaign-finance-data/disbursement-category-code-descriptions/
# Selecting:
# 102: Media Expenditures(presidential filer)
# 103: Expenditures for mass mailings and other campaign materials (presidential filer)
# 004
# 006
# 007

# %% [markdown]
# df_oppexp had negative transaction number. If we only include transaction from presidential filer only, the number doesnt show a lot.

# %%
df_oppexp = abcdefgh.copy()

# %%
abcdefgh.head()
# Out:
#   state    cmte_id category month-year file_name_year  transaction_amt  year
# 0    AK  C00009936      002    2004-07           2004           223.78  2004
# 1    AK  C00011114      002    2004-06           2004          1506.46  2004
# 2    AK  C00011114      002    2004-07           2004          4160.59  2004
# 3    AK  C00011114      002    2004-08           2004          1543.66  2004
# 4    AK  C00011114      002    2004-09           2004           223.77  2004

# %%
df_oppexp.tail()
# Out:
#        state    cmte_id category month-year file_name_year  transaction_amt  \
# 300462    WY  C00567370             2014-07           2014          6883.55
# 300463    WY  C00567370             2014-08           2014          5139.58
# 300464    WY  C00567370             2014-09           2014           206.28
# 300465    WY  C00568808             2014-11           2014          3500.00
# 300466    WY  C00570200      001    2014-11           2014          1329.24
#
#         year
# 300462  2014
# 300463  2014
# 300464  2014
# 300465  2014
# 300466  2014

# %%
df_oppexp['transaction_amt'].hist(bins = 100)
# Out:
# <AxesSubplot:>

# %%
df_oppexp.describe()
# Out:
#        transaction_amt
# count     9.493890e+05
# mean      1.030428e+04
# std       2.586249e+05
# min      -1.024553e+07
# 25%       2.100000e+02
# 50%       8.348000e+02
# 75%       3.650000e+03
# max       1.506886e+08

# %%
print("Sum", df_oppexp[["category", "transaction_amt"]].groupby("category").sum())
print("Mean", df_oppexp[["category", "transaction_amt"]].groupby("category").mean())
print("Mean", df_oppexp[["category", "transaction_amt"]].groupby("category").median())
# Out:
# Sum           transaction_amt
# category
#              5.753195e+09
# '            1.778000e+02
# ---          5.228988e+06
# -01          3.791797e+04
# -99          5.288408e+04
# ...                   ...
# WEB          2.000000e+03
# WI           2.744908e+05
# WV           3.380164e+05
# WY           4.479486e+05
# `            1.396520e+03
#
# [163 rows x 1 columns]
# Mean           transaction_amt
# category
#              16956.370302
# '              177.800000
# ---          70662.002027
# -01           7583.594000
# -99           1510.973714
# ...                   ...
# WEB           1000.000000
# WI            1516.523867
# WV            5281.506250
# WY            3199.633143
# `             1396.520000
#
# [163 rows x 1 columns]
# Mean           transaction_amt
# category
#                   994.705
# '                 177.800
# ---              5452.200
# -01              4500.000
# -99               600.000
# ...                   ...
# WEB              1000.000
# ...

# %%
df_oppexp.isnull().any()
# Out:
# state              False
# cmte_id            False
# category           False
# month-year         False
# file_name_year     False
# transaction_amt    False
# year               False
# dtype: bool

# %%
df_oppexp.isna().sum() # number of null values
# Out:
# state              0
# cmte_id            0
# category           0
# month-year         0
# file_name_year     0
# transaction_amt    0
# year               0
# dtype: int64

# %%
df_oppexp.groupby(["state"])['transaction_amt'].sum()
# Out:
# state
# AK    1.091834e+07
# AL    3.133760e+07
# AR    2.436596e+07
# AZ    1.466130e+08
# CA    6.681390e+08
#           ...
# VT    1.302628e+07
# WA    8.048097e+07
# WI    1.071949e+08
# WV    1.524733e+07
# WY    9.185079e+06
# Name: transaction_amt, Length: 51, dtype: float64

# %%
df_oppexp.groupby(["state"])['transaction_amt'].describe()
# Out:
#          count          mean           std        min       25%       50%  \
# state
# AK      1347.0   8105.674172  19638.774558   -1085.86  299.7900  1515.810
# AL      4568.0   6860.244197  19175.227920   -5000.00  301.1675  1458.470
# AR      4236.0   5752.115250  21073.089078   -2500.00  174.8700   820.075
# AZ     28869.0   5078.563275  40435.650279   -8282.58  117.1100   397.840
# CA     92716.0   7206.297161  55222.939853 -359096.00  153.2075   605.540
# ...        ...           ...           ...        ...       ...       ...
# VT      1773.0   7347.024834  19861.050409   -2000.00  269.0000  1550.570
# WA     19845.0   4055.478670  20160.575490  -28086.07  148.0400   498.200
# WI      9636.0  11124.414607  98180.962135 -177806.53  243.9050  1000.000
# WV      2834.0   5380.144506  15329.187333  -10696.52  300.9700  1500.000
# WY      1138.0   8071.246916  22250.265566   -4700.00  493.9275  2000.000
#
#              75%         max
# state
# AK     6995.5950   332192.00
# ...

# %%
df_oppexp.groupby(['cmte_id'])['state'].unique() # each commitee would spend on multiple states
# Out:
# cmte_id
# C00000422    [AZ, DC, NE, NH, NM, NV, PA, VA, WI, OH, TX, A...
# C00000489                                             [FL, OK]
# C00000638                                         [IN, LA, VA]
# C00000729                                                 [DC]
# C00000885    [CA, CO, CT, DC, FL, IA, IL, IN, MD, MN, MO, O...
#                                    ...
# C00570903                                                 [CO]
# C00571166                                             [LA, NV]
# C00571174                                                 [MA]
# C99002396     [AZ, CA, CO, DC, FL, GA, NY, PA, TX, VA, WA, OR]
# C99003428                                             [NY, WI]
# Name: state, Length: 12164, dtype: object

# %% [markdown]
# Even after filtering for US states.Data is a important to our analysis. We will be dropping empty rows that have null value in the date colum. Category description is not that important column. It is a column that is nice to have. Also dropping empty transaction rows as the number of empty rows is very small compared to the whole dataset.

# %%
df_oppexp.isna().sum()
# Out:
# state              0
# cmte_id            0
# category           0
# month-year         0
# file_name_year     0
# transaction_amt    0
# dtype: int64

# %% [markdown]
# Transaction looks like it is increasing. But it has high variablility and has a lot of negative numbers.  We will thus group it according to month, year, commitee id and

# %%
df_oppexp.plot('month-year', 'transaction_amt')
# Out:
# <AxesSubplot:xlabel='month-year'>

# %% [markdown]
# Expenses on political marketing has been increasing over time

# %%
df_oppexp.groupby(['month-year']).sum('transaction_amt').reset_index().plot('month-year', 'transaction_amt')
# Out:
# <AxesSubplot:xlabel='month-year'>

# %%
df_oppexp.groupby(['year']).sum('transaction_amt').reset_index().plot('year', 'transaction_amt')
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# 004 category has been the highest transaction. 004 is advertising expenses

# %%
df_oppexp.groupby(['category']).sum('transaction_amt').reset_index().plot(x="category", y="transaction_amt", kind = "bar")
# Out:
# <AxesSubplot:xlabel='category'>

# %%
df_oppexp.groupby(['state']).sum('transaction_amt').reset_index().plot(x="state", y="transaction_amt", kind = "bar")
# Out:
# <AxesSubplot:xlabel='state'>

# %% [markdown]
# ## Combining all commitee files from all years

# %%
query_cm = """
SELECT cmte_id, cmte_nm, cmte_st,cmte_pty_affiliation,cand_id, cmte_tp, '2016' AS file_name_year
FROM bigquery-public-data.fec.cm18
UNION ALL 
SELECT cmte_id, cmte_nm, cmte_st,cmte_pty_affiliation,cand_id, cmte_tp, '2016' AS file_name_year
FROM bigquery-public-data.fec.cm16
UNION ALL 
SELECT cmte_id, cmte_nm, cmte_st,cmte_pty_affiliation,cand_id, cmte_tp, '2014' AS file_name_year
FROM bigquery-public-data.fec.cm14
UNION ALL 
SELECT cmte_id, cmte_nm, cmte_st,cmte_pty_affiliation,cand_id, cmte_tp, '2012' AS file_name_year
FROM bigquery-public-data.fec.cm12
UNION ALL 
SELECT cmte_id, cmte_nm, cmte_st,cmte_pty_affiliation,cand_id, cmte_tp, '2010' AS file_name_year
FROM bigquery-public-data.fec.cm10
UNION ALL 
SELECT cmte_id, cmte_nm, cmte_st,cmte_pty_affiliation,cand_id, cmte_tp, '2008' AS file_name_year
FROM bigquery-public-data.fec.cm08
UNION ALL 
SELECT cmte_id, cmte_nm, cmte_st,cmte_pty_affiliation,cand_id, cmte_tp, '2006' AS file_name_year
FROM bigquery-public-data.fec.cm06
UNION ALL 
SELECT cmte_id, cmte_nm, cmte_st,cmte_pty_affiliation,cand_id, cmte_tp, '2004' AS file_name_year
FROM bigquery-public-data.fec.cm04
"""

# %%
query_job_cm = bigquery_client.query(query_cm)

# %%
df_cm = query_job_cm.to_dataframe()
# Out:
# /usr/local/lib/python3.8/site-packages/google/cloud/bigquery/client.py:440: UserWarning: Cannot create BigQuery Storage client, the dependency google-cloud-bigquery-storage is not installed.
#   warnings.warn(

# %%
df_cm.tail()
# Out:
#           cmte_id                                            cmte_nm cmte_st  \
# 105786  C00011387  COLORADO ADVOCATES FOR RURAL ELECTRIFICATION (...      CO
# 105787  C00022756  DARIGOLD POLITICAL ACTION COMMITTEE (FKA NORTH...      WA
# 105788  C00032797                      NATIONAL GOOD GOVERNMENT FUND      TX
# 105789  C00034256  NATIONAL WOMEN'S POLITICAL CAUCUS CAMPAIGN SUP...      DC
# 105790  C00034728    TRUE COMPANIES RESPONSIBLE GOVERNMENT COMMITTEE      WY
#
#        cmte_pty_affiliation cand_id cmte_tp file_name_year
# 105786                  UNK    None       Q           2008
# 105787                  UNK    None       Q           2008
# 105788                  UNK    None       Q           2008
# 105789                  UNK    None       Q           2008
# 105790                  UNK    None       Q           2008

# %%
df_cm.shape
# Out:
# (123863, 7)

# %%
df_cm.isnull().any()
# Out:
# cmte_id                 False
# cmte_nm                  True
# cmte_st                 False
# cmte_pty_affiliation     True
# cand_id                  True
# cmte_tp                  True
# file_name_year          False
# dtype: bool

# %%
df_cm['cmte_nm'].unique()
# Out:
# array(['EMPOWER ILLINOIS MEDIA FUND',
#        'RESPONSIBLE GOVERNMENT COMMITTEE OF GULF POWER COMPANY EMPLOYEES INC',
#        'BUCHANAN REFORM INC', ..., 'GREEN RAINBOW PARTY FEDERAL FUND',
#        'GEORGIA REPUBLICAN PARTY INC.',
#        'ILLINOIS REPUBLICAN PARTY - FEDERAL'], dtype=object)

# %%
df_cm.groupby(['cmte_id'])['cmte_nm'].unique() # number of unique cmte_id is around 45499
# Out:
# cmte_id
# C00000018    [IRONWORKERS LOCAL UNION NO. 25 POLITICAL EDUC...
# C00000042    [ILLINOIS TOOL WORKS FOR BETTER GOVERNMENT COM...
# C00000059    [HALLMARK POLITICAL ACTION COMMITTEE-FEDERAL H...
# C00000125                      [ARCHER FOR CONGRESS COMMITTEE]
# C00000372    [MAINTENANCE OF WAY POLITICAL LEAGUE A PAC OF ...
#                                    ...
# C90020926                                   [CUFI ACTION FUND]
# C90020934                               [AMERICA PROGRESS NOW]
# C99002396                [AMERICAN POLITICAL ACTION COMMITTEE]
# C99003329                                               [CORK]
# C99003428                    [THIRD DISTRICT REPUBLICAN PARTY]
# Name: cmte_nm, Length: 45510, dtype: object

# %%
df_cm.shape
# Out:
# (123863, 7)

# %%
df_cm = df_cm.loc[df_cm['cmte_st'].isin(["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
                                         "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", 
                                         "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", 
                                         "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", 
                                         "UT", "VT", "VA", "WA", "WV", "WI", "WY"])]

# %%
df_cm.groupby(["cmte_st"])['cmte_pty_affiliation'].count()
# Out:
# cmte_st
# AK     274
# AL     729
# AR     470
# AZ    1414
# CA    7255
# CO    1152
# CT     775
# DC    4050
# DE     262
# FL    5123
# GA    1703
# HI     399
# IA     631
# ID     325
# IL    2228
# IN    1113
# KS     578
# KY     690
# LA     855
# MA    1118
# MD    1491
# ME     283
# MI    2063
# MN    1173
# MO    1111
# MS     476
# MT     307
# NC    1672
# ND     168
# NE     411
# NH     417
# NJ    1459
# NM     475
# NV     737
# NY    3301
# OH    2034
# OK     677
# OR     654
# PA    2217
# RI     285
# SC     780
# SD     194
# TN    1242
# TX    4125
# UT     633
# VA    3647
# VT     168
# WA    1200
# WI     943
# WV     402
# WY     175
# Name: cmte_pty_affiliation, dtype: int64

# %%
df_cm.shape
# Out:
# (123608, 7)

# %%
df_cm.groupby(['cmte_id'])['cmte_nm'].unique()
# Out:
# cmte_id
# C00000018    [IRONWORKERS LOCAL UNION NO. 25 POLITICAL EDUC...
# C00000042    [ILLINOIS TOOL WORKS FOR BETTER GOVERNMENT COM...
# C00000059    [HALLMARK POLITICAL ACTION COMMITTEE-FEDERAL H...
# C00000125                      [ARCHER FOR CONGRESS COMMITTEE]
# C00000372    [MAINTENANCE OF WAY POLITICAL LEAGUE A PAC OF ...
#                                    ...
# C90020926                                   [CUFI ACTION FUND]
# C90020934                               [AMERICA PROGRESS NOW]
# C99002396                [AMERICAN POLITICAL ACTION COMMITTEE]
# C99003329                                               [CORK]
# C99003428                    [THIRD DISTRICT REPUBLICAN PARTY]
# Name: cmte_nm, Length: 45404, dtype: object

# %%
df_cm.sort_values(['cmte_id'], ascending = False).head(100)
# Out:
#           cmte_id                                            cmte_nm cmte_st  \
# 105748  C99003428                    THIRD DISTRICT REPUBLICAN PARTY      WI
# 88099   C99003428                    THIRD DISTRICT REPUBLICAN PARTY      WI
# 39651   C99003428                    THIRD DISTRICT REPUBLICAN PARTY      WI
# 28420   C99003428                    THIRD DISTRICT REPUBLICAN PARTY      WI
# 58739   C99003428                    THIRD DISTRICT REPUBLICAN PARTY      WI
# 9083    C99003428                    THIRD DISTRICT REPUBLICAN PARTY      WI
# 18382   C99003428                    THIRD DISTRICT REPUBLICAN PARTY      WI
# 73642   C99003428                    THIRD DISTRICT REPUBLICAN PARTY      WI
# 3578    C99003329                                               CORK      WA
# 56342   C99002396                AMERICAN POLITICAL ACTION COMMITTEE      WA
# 7627    C99002396                AMERICAN POLITICAL ACTION COMMITTEE      WA
# ...

# %%
#exploring commitees that are counted more than once
v = df_cm.cmte_id.value_counts()
double_cm = df_cm[df_cm.cmte_id.isin(v.index[v.gt(1)])].sort_values(['cmte_id'], ascending = False)
double_cm.head(200)
# Out:
#           cmte_id                                            cmte_nm cmte_st  \
# 39651   C99003428                    THIRD DISTRICT REPUBLICAN PARTY      WI
# 58739   C99003428                    THIRD DISTRICT REPUBLICAN PARTY      WI
# 28420   C99003428                    THIRD DISTRICT REPUBLICAN PARTY      WI
# 9083    C99003428                    THIRD DISTRICT REPUBLICAN PARTY      WI
# 73642   C99003428                    THIRD DISTRICT REPUBLICAN PARTY      WI
# 18382   C99003428                    THIRD DISTRICT REPUBLICAN PARTY      WI
# 88099   C99003428                    THIRD DISTRICT REPUBLICAN PARTY      WI
# 105748  C99003428                    THIRD DISTRICT REPUBLICAN PARTY      WI
# 27106   C99002396                AMERICAN POLITICAL ACTION COMMITTEE      WA
# 56342   C99002396                AMERICAN POLITICAL ACTION COMMITTEE      WA
# 7627    C99002396                AMERICAN POLITICAL ACTION COMMITTEE      WA
# ...

# %% [markdown]
# ## Combining all Commitee-Candidate linkage files

# %%
query_ccl = """
SELECT cand_id, cand_election_yr, fec_election_yr, cmte_id, cmte_tp, '2018' AS file_name_year
FROM bigquery-public-data.fec.ccl18
UNION ALL
SELECT cand_id, cand_election_yr, fec_election_yr, cmte_id, cmte_tp, '2016' AS file_name_year
FROM bigquery-public-data.fec.ccl16
UNION ALL
SELECT cand_id, cand_election_yr, fec_election_yr, cmte_id, cmte_tp, '2014' AS file_name_year
FROM bigquery-public-data.fec.ccl14
UNION ALL
SELECT cand_id, cand_election_yr, fec_election_yr, cmte_id, cmte_tp, '2012' AS file_name_year
FROM bigquery-public-data.fec.ccl12
UNION ALL
SELECT cand_id, cand_election_yr, fec_election_yr, cmte_id, cmte_tp, '2010' AS file_name_year
FROM bigquery-public-data.fec.ccl10
UNION ALL
SELECT cand_id, cand_election_yr, fec_election_yr, cmte_id, cmte_tp, '2008' AS file_name_year
FROM bigquery-public-data.fec.ccl08
UNION ALL
SELECT cand_id, cand_election_yr, fec_election_yr, cmte_id, cmte_tp, '2006' AS file_name_year
FROM bigquery-public-data.fec.ccl06
UNION ALL
SELECT cand_id, cand_election_yr, fec_election_yr, cmte_id, cmte_tp, '2004' AS file_name_year
FROM bigquery-public-data.fec.ccl04
"""

# %%
query_job_ccl = bigquery_client.query(query_ccl)

# %%
df_ccl = query_job_ccl.to_dataframe()
# Out:
# /usr/local/lib/python3.8/site-packages/google/cloud/bigquery/client.py:440: UserWarning: Cannot create BigQuery Storage client, the dependency google-cloud-bigquery-storage is not installed.
#   warnings.warn(

# %%
df_ccl.head()
# Out:
#      cand_id  cand_election_yr  fec_election_yr    cmte_id cmte_tp  \
# 0  H0CT05085              1996             2008  C00281402       H
# 1  H8MI13102              1996             2008  C00245712       H
# 2  H6MO01022              1998             2008  C00060582       H
# 3  H6OK03116              2002             2008  C00312884       H
# 4  H2OK05128              2004             2008  C00374801       H
#
#   file_name_year
# 0           2008
# 1           2008
# 2           2008
# 3           2008
# 4           2008

# %%
df_ccl.tail()
# Out:
#          cand_id  cand_election_yr  fec_election_yr    cmte_id cmte_tp  \
# 50143  P80003338              2008             2006  C00431130       U
# 50144  P80003692              2008             2006  C00429639       U
# 50145  S2CA00286              2010             2006  C00388835       U
# 50146  S6AZ00019              2010             2006  C00412916       U
# 50147  H8TX06035              2006             2006  C00041269       Y
#
#       file_name_year
# 50143           2006
# 50144           2006
# 50145           2006
# 50146           2006
# 50147           2006

# %%
df_ccl.isnull().any()
# Out:
# cand_id             False
# cand_election_yr    False
# fec_election_yr     False
# cmte_id             False
# cmte_tp             False
# file_name_year      False
# dtype: bool

# %%
df_ccl.shape
# Out:
# (50148, 6)

# %% [markdown]
# ## Combining all Candidate files

# %%
query_cn = """
SELECT cand_id, cand_election_yr, cand_name, cand_pty_affiliation, cand_office_st, cand_office, cand_pcc, cand_status, cand_ici, '2018' AS file_name_year
FROM bigquery-public-data.fec.cn18
UNION ALL
SELECT cand_id, cand_election_yr, cand_name, cand_pty_affiliation, cand_office_st, cand_office, cand_pcc, cand_status, cand_ici, '2016' AS file_name_year
FROM bigquery-public-data.fec.cn16
UNION ALL
SELECT cand_id, cand_election_yr, cand_name, cand_pty_affiliation, cand_office_st, cand_office, cand_pcc, cand_status, cand_ici, '2014' AS file_name_year
FROM bigquery-public-data.fec.cn14
UNION ALL
SELECT cand_id, cand_election_yr, cand_name, cand_pty_affiliation, cand_office_st, cand_office, cand_pcc, cand_status, cand_ici, '2012' AS file_name_year
FROM bigquery-public-data.fec.cn12
UNION ALL
SELECT cand_id, cand_election_yr, cand_name, cand_pty_affiliation, cand_office_st, cand_office, cand_pcc, cand_status, cand_ici, '2010' AS file_name_year
FROM bigquery-public-data.fec.cn10
UNION ALL
SELECT cand_id, cand_election_yr, cand_name, cand_pty_affiliation, cand_office_st, cand_office, cand_pcc, cand_status, cand_ici, '2008' AS file_name_year
FROM bigquery-public-data.fec.cn08
UNION ALL
SELECT cand_id, cand_election_yr, cand_name, cand_pty_affiliation, cand_office_st, cand_office, cand_pcc, cand_status, cand_ici, '2006' AS file_name_year
FROM bigquery-public-data.fec.cn06
UNION ALL
SELECT cand_id, cand_election_yr, cand_name, cand_pty_affiliation, cand_office_st, cand_office, cand_pcc, cand_status, cand_ici, '2004' AS file_name_year
FROM bigquery-public-data.fec.cn04
"""

# %%
query_job_cn = bigquery_client.query(query_cn)

# %%
df_cn = query_job_cn.to_dataframe()

# %%
df_cn.head()
# Out:
#      cand_id  cand_election_yr                   cand_name  \
# 0  H4PR00053              2004  COLON CHARLES A. RODRIGUEZ
# 1  H4PA17083              2004          LOTWICK JOHN R MR.
# 2  H4MN05055              2004                FRANSON DICK
# 3  H0PR00077              2004         MORA EDWIN IRIZARRY
# 4  H4PR00087              2004       GARCIA MYRIAM RAMIREZ
#
#   cand_pty_affiliation cand_office_st cand_office   cand_pcc cand_status  \
# 0                  NPP             PR           H  C00386037           C
# 1                  Rep             PA           H  C00393710           C
# 2                  DFL             MN           H  C00389742           C
# 3                  NPP             PR           H       None           N
# 4                  NPP             PR           H       None           N
#
#   cand_ici file_name_year
# 0        C           2004
# 1        C           2004
# 2        C           2004
# 3        C           2004
# 4        C           2004

# %%
df_ccl.isnull().any()
# Out:
# cand_id             False
# cand_election_yr    False
# fec_election_yr     False
# cmte_id             False
# cmte_tp             False
# file_name_year      False
# dtype: bool

# %%
df_ccl.shape
# Out:
# (50148, 6)

# %% [markdown]
# ## Joining oppexp, cm, ccl and cn datasets

# %%
df_oppexp1 = abcdefgh.copy()

# %%
df_oppexp1.shape
# Out:
# (1223244, 7)

# %%
df_oppexp1.head()
# Out:
#   state    cmte_id category month-year file_name_year  transaction_amt  year
# 0    AK  C00009936      002    2004-07           2004           223.78  2004
# 1    AK  C00011114      002    2004-06           2004          1506.46  2004
# 2    AK  C00011114      002    2004-07           2004          4160.59  2004
# 3    AK  C00011114      002    2004-08           2004          1543.66  2004
# 4    AK  C00011114      002    2004-09           2004           223.77  2004

# %%
df_cm.dtypes
# Out:
# cmte_id                 object
# cmte_nm                 object
# cmte_st                 object
# cmte_pty_affiliation    object
# cand_id                 object
# cmte_tp                 object
# file_name_year          object
# dtype: object

# %%
df_oppexp1.dtypes
# Out:
# state               object
# cmte_id             object
# category            object
# month-year          object
# file_name_year      object
# transaction_amt    float64
# year                object
# dtype: object

# %%
df_oppexp1['file_name_year']= df_oppexp1['file_name_year'].astype(str)

# %%
df1 = df_oppexp1.merge(df_cm, on=['cmte_id', 'file_name_year'], how='inner')

# %%
df1.tail()
# Out:
#         state    cmte_id category month-year file_name_year  transaction_amt  \
# 1199101    WY  C00276485      003    2015-12           2016           521.72
# 1199102    WY  C00276485      003    2016-06           2016            53.50
# 1199103    WY  C00276485      003    2016-06           2016            53.50
# 1199104    WY  C00532721      001    2016-10           2016            10.69
# 1199105    WY  C00532721      001    2016-10           2016            10.69
#
#          year                                 cmte_nm cmte_st  \
# 1199101  2015  WYOMING RURAL ELECTRIC ASSOCIATION PAC      WY
# 1199102  2016  WYOMING RURAL ELECTRIC ASSOCIATION PAC      WY
# 1199103  2016  WYOMING RURAL ELECTRIC ASSOCIATION PAC      WY
# 1199104  2016                     CUMMINGS 4 CONGRESS      WY
# 1199105  2016                     CUMMINGS 4 CONGRESS      WY
#
#         cmte_pty_affiliation    cand_id cmte_tp
# 1199101                 None       None       Q
# ...

# %%
df1.shape
# Out:
# (1199106, 12)

# %%
df1.isna().sum()
# Out:
# state                        0
# cmte_id                      0
# category                     0
# month-year                   0
# file_name_year               0
# transaction_amt              0
# year                         0
# cmte_nm                      0
# cmte_st                    267
# cmte_pty_affiliation    137331
# cand_id                 169264
# cmte_tp                      0
# dtype: int64

# %%
df2 = df1.merge(df_ccl, on=['cmte_id', 'file_name_year', 'cand_id'], how='inner')

# %%
df2.head()
# Out:
#   state    cmte_id category month-year file_name_year  transaction_amt  year  \
# 0    AK  C00261370      002    2004-07           2004           547.80  2004
# 1    AZ  C00261370      001    2003-01           2004          1276.56  2003
# 2    AZ  C00261370      001    2003-02           2004            71.80  2003
# 3    AZ  C00261370      001    2003-03           2004           511.62  2003
# 4    AZ  C00261370      001    2003-04           2004           481.69  2003
#
#                       cmte_nm cmte_st cmte_pty_affiliation    cand_id  \
# 0  RICHARD POMBO FOR CONGRESS      CA                  REP  H2CA11051
# 1  RICHARD POMBO FOR CONGRESS      CA                  REP  H2CA11051
# 2  RICHARD POMBO FOR CONGRESS      CA                  REP  H2CA11051
# 3  RICHARD POMBO FOR CONGRESS      CA                  REP  H2CA11051
# 4  RICHARD POMBO FOR CONGRESS      CA                  REP  H2CA11051
#
#   cmte_tp_x  cand_election_yr  fec_election_yr cmte_tp_y
# ...

# %%
df2.shape
# Out:
# (843479, 15)

# %%
df3 = df2.merge(df_cn, on=['file_name_year', 'cand_id'], how='inner')

# %%
df3.head()
# Out:
#   state    cmte_id category month-year file_name_year  transaction_amt  year  \
# 0    AK  C00261370      002    2004-07           2004           547.80  2004
# 1    AZ  C00261370      001    2003-01           2004          1276.56  2003
# 2    AZ  C00261370      001    2003-02           2004            71.80  2003
# 3    AZ  C00261370      001    2003-03           2004           511.62  2003
# 4    AZ  C00261370      001    2003-04           2004           481.69  2003
#
#                       cmte_nm cmte_st cmte_pty_affiliation    cand_id  \
# 0  RICHARD POMBO FOR CONGRESS      CA                  REP  H2CA11051
# 1  RICHARD POMBO FOR CONGRESS      CA                  REP  H2CA11051
# 2  RICHARD POMBO FOR CONGRESS      CA                  REP  H2CA11051
# 3  RICHARD POMBO FOR CONGRESS      CA                  REP  H2CA11051
# 4  RICHARD POMBO FOR CONGRESS      CA                  REP  H2CA11051
#
#   cmte_tp_x  cand_election_yr_x  fec_election_yr cmte_tp_y  \
# ...

# %%
df3.to_csv("all_fec.csv")

# %%
df3.shape
# Out:
# (843479, 23)

# %%
df3.isnull().any()
# Out:
# state                   False
# cmte_id                 False
# category                False
# month-year              False
# file_name_year          False
# transaction_amt         False
# year                    False
# cmte_nm                 False
# cmte_st                  True
# cmte_pty_affiliation     True
# cand_id                 False
# cmte_tp_x               False
# cand_election_yr_x      False
# fec_election_yr         False
# cmte_tp_y               False
# cand_election_yr_y      False
# cand_name               False
# cand_pty_affiliation     True
# cand_office_st          False
# cand_office             False
# cand_pcc                 True
# cand_status              True
# cand_ici                 True
# dtype: bool

# %%
df3.isna().sum()
# Out:
# state                       0
# cmte_id                     0
# category                    0
# month-year                  0
# file_name_year              0
# transaction_amt             0
# year                        0
# cmte_nm                     0
# cmte_st                   267
# cmte_pty_affiliation    14746
# cand_id                     0
# cmte_tp_x                   0
# cand_election_yr_x          0
# fec_election_yr             0
# cmte_tp_y                   0
# cand_election_yr_y          0
# cand_name                   0
# cand_pty_affiliation       22
# cand_office_st              0
# cand_office                 0
# cand_pcc                  636
# cand_status               370
# cand_ici                  647
# dtype: int64

# %%
df3.nunique()
# Out:
# state                       51
# cmte_id                   9326
# category                   177
# month-year                 250
# file_name_year               8
# transaction_amt         397417
# year                        32
# cmte_nm                   9292
# cmte_st                     60
# cmte_pty_affiliation        44
# cand_id                   8018
# cmte_tp_x                   11
# cand_election_yr_x          26
# fec_election_yr              8
# cmte_tp_y                   12
# cand_election_yr_y          26
# cand_name                 9588
# cand_pty_affiliation        37
# cand_office_st              57
# cand_office                  3
# cand_pcc                  8106
# cand_status                  4
# cand_ici                     4
# dtype: int64

# %%
df3.dtypes
# Out:
# state                    object
# cmte_id                  object
# category                 object
# month-year               object
# file_name_year           object
# transaction_amt         float64
# year                     object
# cmte_nm                  object
# cmte_st                  object
# cmte_pty_affiliation     object
# cand_id                  object
# cmte_tp_x                object
# cand_election_yr_x        int64
# fec_election_yr           int64
# cmte_tp_y                object
# cand_election_yr_y        int64
# cand_name                object
# cand_pty_affiliation     object
# cand_office_st           object
# cand_office              object
# cand_pcc                 object
# cand_status              object
# cand_ici                 object
# dtype: object

# %%
df3['cmte_tp_x'].unique()
# Out:
# array(['H', 'P', 'X', 'D', 'N', 'U', 'S', 'Q', 'Y', 'O', 'V'],
#       dtype=object)

# %%
df3['cmte_tp_y'].unique() # use this and drop the other one
# Out:
# array(['H', 'P', 'X', 'D', 'N', 'U', 'S', 'Q', 'Y', 'I', 'O', 'V'],
#       dtype=object)

# %%
df3.loc[df3['cmte_tp_y'].isin(['I'])].head()
# Out:
#        state    cmte_id category month-year file_name_year  transaction_amt  \
# 105001    AZ  C00430892      001    2007-07           2008            56.41
# 105002    AZ  C00430892      001    2007-08           2008           119.82
# 105003    AZ  C00430892      001    2007-09           2008           239.07
# 105004    AZ  C00430892      001    2007-10           2008           110.00
# 105005    CA  C00430892      001    2007-01           2008            35.28
#
#         year                  cmte_nm cmte_st cmte_pty_affiliation    cand_id  \
# 105001  2007  CALIFORNIANS FOR CHANGE      CA                 None  P80003338
# 105002  2007  CALIFORNIANS FOR CHANGE      CA                 None  P80003338
# 105003  2007  CALIFORNIANS FOR CHANGE      CA                 None  P80003338
# 105004  2007  CALIFORNIANS FOR CHANGE      CA                 None  P80003338
# 105005  2007  CALIFORNIANS FOR CHANGE      CA                 None  P80003338
#
# ...

# %%
df3.loc[df3['cmte_tp_y'].isin(['I'])]
# Out:
#        state    cmte_id category month-year file_name_year  transaction_amt  \
# 105001    AZ  C00430892      001    2007-07           2008            56.41
# 105002    AZ  C00430892      001    2007-08           2008           119.82
# 105003    AZ  C00430892      001    2007-09           2008           239.07
# 105004    AZ  C00430892      001    2007-10           2008           110.00
# 105005    CA  C00430892      001    2007-01           2008            35.28
# 105006    CA  C00430892      001    2007-02           2008           967.23
# 105007    CA  C00430892      001    2007-03           2008          1918.24
# 105008    CA  C00430892      001    2007-04           2008           310.14
# 105009    CA  C00430892      001    2007-05           2008           647.95
# 105010    CA  C00430892      001    2007-06           2008          1360.11
# 105011    CA  C00430892      001    2007-07           2008           761.68
# ...

# %%
df3['cand_election_yr_x'].unique()
# Out:
# array([2004, 2002, 2003, 2000, 1998, 2006, 2001, 2008, 1992, 1996, 2010,
#        2005, 1994, 2007, 2012, 2009, 2014, 1990, 2016, 2011, 2013, 2018,
#        2020, 2015, 2017, 2022])

# %%
df3['fec_election_yr'].unique()
# Out:
# array([2004, 2006, 2008, 2010, 2012, 2014, 2016, 2018])

# %%
df3['cand_election_yr_y'].unique()# have years that are not between 2004-2012
# Out:
# array([2004, 2002, 2003, 2000, 1998, 2006, 2001, 2008, 1992, 1996, 2010,
#        2005, 1994, 2007, 2012, 2009, 2014, 1990, 2016, 2011, 2013, 2018,
#        2020, 2015, 2017, 2022])

# %%
pres = df3.loc[df3['cand_office'].isin(['P'])

# %%
pres = df3.loc[df3['cand_election_yr_y'].isin(['2004','2008', '2012', '2016'])]

# %%
pres['cand_election_yr_y'].unique()
# Out:
# array([2004, 2008, 2012, 2016])

# %%
df3.loc[df3['cand_election_yr_y'].isin(['1996'])]
# Out:
#        state    cmte_id category month-year file_name_year  transaction_amt  \
# 47997     VA  C00321216      001    2004-09           2004           150.00
# 49040     AL  C00303610       AL    2005-10           2006           744.59
# 49041     AL  C00303610       AL    2006-03           2006           486.00
# 49042     AL  C00303610       AL    2006-04           2006            87.00
# 49043     AL  C00303610       AL    2006-10           2006           563.00
# 108902    AL  C00303610       AL    2007-04           2008           593.00
# 108903    AL  C00303610       AL    2007-08           2008           290.00
# 108904    AL  C00303610       AL    2007-10           2008           423.00
# 108905    AL  C00303610       AL    2008-04           2008           111.00
# 108906    AL  C00303610       AL    2008-07           2008           211.00
# 168771    VA  C00301465      101    2008-03           2008         10581.26
# ...

# %%
df3.dtypes
# Out:
# state                    object
# cmte_id                  object
# category                 object
# month-year               object
# file_name_year           object
# transaction_amt         float64
# year                     object
# cmte_nm                  object
# cmte_st                  object
# cmte_pty_affiliation     object
# cand_id                  object
# cmte_tp_x                object
# cand_election_yr_x        int64
# fec_election_yr           int64
# cmte_tp_y                object
# cand_election_yr_y        int64
# cand_name                object
# cand_pty_affiliation     object
# cand_office_st           object
# cand_office              object
# cand_pcc                 object
# cand_status              object
# cand_ici                 object
# dtype: object

# %%
df3["fec_election_yr"] = pd.to_datetime(df3['fec_election_yr'], format='%Y') 
df3["cand_election_yr_x"] = pd.to_datetime(df3['cand_election_yr_x'], format='%Y')

# %%
df3.groupby(["category"]).describe()
# Out:
#          transaction_amt                                                   \
#                    count          mean            std       min       25%
# category
# 004              62372.0  24624.638602  150225.901962 -16634.15  342.0375
# 006              32631.0   4655.548553   21413.198038  -5050.00  289.3900
# 007              33095.0   2269.931488   13985.022972 -11049.99  258.0000
# 102                231.0   9423.614502   31719.505596     10.23  642.5000
# 103                108.0   5524.336759   13160.163804     45.00  396.3875
#
#                                           cand_election_yr_x               \
#               50%        75%          max              count         mean
# category
# 004       1300.00  6187.3400  10500000.00            62372.0  2013.443436
# 006        824.74  2691.2500   1309402.87            32631.0  2012.783611
# 007        650.00  1850.0000   1867665.00            33095.0  2012.787914
# ...

# %%
df_cn.head()
# Out:
#      cand_id  cand_election_yr                 cand_name cand_pty_affiliation  \
# 0  H6CO04152              2006  EIDSNESS FREDERIC ARNOLD                  REF
# 1  H6NY04120              2006       BLESSINGER MARTIN W                  CON
# 2  H6NY11166              2006           MCCLEAN OLLIE M                  FRE
# 3  H6FL22065              2006    EVANGELISTA NEIL JAMES                  NPA
# 4  H6FL12157              2006          VISCUSI JOSEPH A                  NPA
#
#   cand_office_st cand_office   cand_pcc cand_status cand_ici file_name_year
# 0             CO           H  C00424564           C        C           2006
# 1             NY           H  C00426106           C        C           2006
# 2             NY           H  C00428235           C        C           2006
# 3             FL           H  C00426924           C        C           2006
# 4             FL           H  C00425017           C        C           2006

# %%
df_cn['file_name_year'].unique()
# Out:
# array(['2006', '2004', '2008', '2014', '2012', '2016', '2018', '2020',
#        '2010'], dtype=object)

# %% [markdown]
# # Testing(Not relevant right now)

# %%
test_query = """
SELECT A.cmte_id, B.cmte_nm, C.cand_name, C.cand_election_yr, C.cand_office, C.cand_office_st, 
C.cand_pty_affiliation, B.cmte_st,B.cmte_pty_affiliation, B.cand_id,
A.transaction_amt, A.transaction_dt, A.category, A.category_desc, A.state
FROM `bigquery-public-data.fec.oppexp20` A, `bigquery-public-data.fec.cm20` B, `bigquery-public-data.fec.cn20` C
WHERE (category = '102' OR  category = '103' OR  category = '004' OR  category = '006' 
OR  category = '007') AND A.cmte_id = B.cmte_id and B.cand_id = C.cand_id;
"""
query_job_test = bigquery_client.query(test_query)
df_test = query_job_test.to_dataframe()
df_test.head()

# %%
test_query2 = """
SELECT A.cmte_id, B.cmte_nm, C.cand_name, C.cand_election_yr, C.cand_office, C.cand_office_st, 
C.cand_pty_affiliation, B.cmte_st,B.cmte_pty_affiliation, B.cand_id,
A.transaction_amt, A.transaction_dt, A.category, A.category_desc, A.state
FROM `bigquery-public-data.fec.oppexp20` A, `bigquery-public-data.fec.cm20` B, `bigquery-public-data.fec.cn20` C,
`bigquery-public-data.fec.ccl20` D
WHERE (category = '102' OR  category = '103' OR  category = '004' OR  category = '006' 
OR  category = '007') AND A.cmte_id = B.cmte_id and B.cmte_id = D.cmte_id and D.cand_id = C.cand_id;
"""
query_job_test2 = bigquery_client.query(test_query2)
df_test2 = query_job_test2.to_dataframe()
df_test2.head()
# Out:
# /usr/local/lib/python3.8/site-packages/google/cloud/bigquery/client.py:440: UserWarning: Cannot create BigQuery Storage client, the dependency google-cloud-bigquery-storage is not installed.
#   warnings.warn(
#      cmte_id                         cmte_nm            cand_name  \
# 0  C00741397  TASK FORCE GRIGGS FOR CONGRESS  GRIGGS, JOYCE MARIE
# 1  C00741397  TASK FORCE GRIGGS FOR CONGRESS  GRIGGS, JOYCE MARIE
# 2  C00741397  TASK FORCE GRIGGS FOR CONGRESS  GRIGGS, JOYCE MARIE
# 3  C00741397  TASK FORCE GRIGGS FOR CONGRESS  GRIGGS, JOYCE MARIE
# 4  C00741397  TASK FORCE GRIGGS FOR CONGRESS  GRIGGS, JOYCE MARIE
#
#    cand_election_yr cand_office cand_office_st cand_pty_affiliation cmte_st  \
# 0              2000           H             GA                  DEM      GA
# 1              2000           H             GA                  DEM      GA
# 2              2000           H             GA                  DEM      GA
# ...

# %%
test_oppexp = """
SELECT A.cmte_id,
A.transaction_amt, A.transaction_dt, A.category, A.category_desc, A.state
FROM `bigquery-public-data.fec.oppexp20` A
WHERE category = '102' OR  category = '103' OR  category = '004' OR  category = '006' 
OR  category = '007'
"""
query_test_oppexp = bigquery_client.query(test_oppexp)
df_oppexp = query_test_oppexp.to_dataframe()
df_oppexp.head()
# Out:
# /usr/local/lib/python3.8/site-packages/google/cloud/bigquery/client.py:440: UserWarning: Cannot create BigQuery Storage client, the dependency google-cloud-bigquery-storage is not installed.
#   warnings.warn(
#      cmte_id  transaction_amt transaction_dt category  \
# 0  C00690586             75.0     2019-06-20      004
# 1  C00436386           1500.0     2019-01-23      007
# 2  C00469882            600.0     2019-07-31      007
# 3  C00648295            500.0     2020-06-26      007
# 4  C00703413             75.0     2020-04-07      007
#
#              category_desc state
# 0    Advertising Expenses     ND
# 1  Campaign Event Expenses    WY
# 2  Campaign Event Expenses    MP
# 3  Campaign Event Expenses    ID
# 4  Campaign Event Expenses    ME

# %%
print(df_oppexp.shape)
print(df_cm.shape)
print(df_cn.shape)
print(df_test.shape)
print(df_test2.shape)
# Out:
# (42756, 6)
# (18177, 5)
# (7794, 6)
# (38108, 15)
# (39027, 17)

# %%
print(df_cm.isna().sum())
print(df_cn.isna().sum())
# Out:
# cmte_nm                     2
# cmte_st                     8
# cmte_pty_affiliation    10399
# cand_id                 11431
# cmte_id                     0
# dtype: int64
# cand_name               0
# cand_election_yr        0
# cand_office             0
# cand_office_st          0
# cand_id                 0
# cand_pty_affiliation    5
# dtype: int64

# %%
print(df_test.isna().sum())
print(df_test2.isna().sum())
# Out:
# cmte_id                   0
# cmte_nm                   0
# cand_name                 0
# cand_election_yr          0
# cand_office               0
# cand_office_st            0
# cand_pty_affiliation      0
# cmte_st                   0
# cmte_pty_affiliation     81
# cand_id                   0
# transaction_amt           0
# transaction_dt            0
# category                  0
# category_desc           104
# state                   410
# dtype: int64
# cmte_id                   0
# cmte_nm                   0
# cand_name                 0
# cand_election_yr          0
# cand_office               0
# cand_office_st            0
# cand_pty_affiliation      0
# cmte_st                   0
# cmte_pty_affiliation     81
# cand_id                   0
# transaction_amt           0
# transaction_dt            0
# category                  0
# category_desc           104
# state                   430
# cand_id_1                 0
# cmte_id_1                 0
# dtype: int64

# %%
test_cm = """
SELECT B.cmte_nm, B.cmte_st,B.cmte_pty_affiliation, B.cand_id, B.cmte_id
FROM `bigquery-public-data.fec.cm20` B
"""
query_test_cm = bigquery_client.query(test_cm)
df_cm = query_test_cm.to_dataframe()
df_cm.head()
# Out:
# /usr/local/lib/python3.8/site-packages/google/cloud/bigquery/client.py:440: UserWarning: Cannot create BigQuery Storage client, the dependency google-cloud-bigquery-storage is not installed.
#   warnings.warn(
#                                              cmte_nm cmte_st  \
# 0                                               None    None
# 1                                               None    None
# 2                                FREEDOM FOR ALL 777    None
# 3                                ARIZONA FOR AMERICA      VA
# 4  THE COMMITTEE TO ELECT ROBERT D MCGEE FOR PRES...      NC
#
#   cmte_pty_affiliation    cand_id    cmte_id
# 0                 None       None  C00669044
# 1                 None  H8PA13158  C00677690
# 2                 None       None  C00690214
# 3                 None       None  C00703348
# 4                 None  P60015591  C00754986

# %%
test_cn = """
SELECT C.cand_name, C.cand_election_yr, C.cand_office, C.cand_office_st, C.cand_id,
C.cand_pty_affiliation 
FROM `bigquery-public-data.fec.cn20` C
"""
query_test_cn = bigquery_client.query(test_cn)
df_cn = query_test_cn.to_dataframe()
df_cn.head()
# Out:
# /usr/local/lib/python3.8/site-packages/google/cloud/bigquery/client.py:440: UserWarning: Cannot create BigQuery Storage client, the dependency google-cloud-bigquery-storage is not installed.
#   warnings.warn(
#           cand_name  cand_election_yr cand_office cand_office_st    cand_id  \
# 0      ROBY, MARTHA              2020           H             AL  H0AL02087
# 1     WOMACK, STEVE              2020           H             AR  H0AR03055
# 2     BERA, AMERISH              2020           H             CA  H0CA03078
# 3  DESAULNIER, MARK              2020           H             CA  H0CA10073
# 4   GARAMENDI, JOHN              2020           H             CA  H0CA10149
#
#   cand_pty_affiliation
# 0                  REP
# 1                  REP
# 2                  DEM
# 3                  DEM
# 4                  DEM

# %%
bigquery_client = bigquery.Client()
query_job_test = bigquery_client.query(test_query)

# %%
df_test = query_job_test.to_dataframe()
# Out:
# /usr/local/lib/python3.8/site-packages/google/cloud/bigquery/client.py:440: UserWarning: Cannot create BigQuery Storage client, the dependency google-cloud-bigquery-storage is not installed.
#   warnings.warn(

# %%
df_test.tail()
# Out:
#          cmte_id                           cmte_nm               cand_name  \
# 38103  C00735365           FRIENDS OF MATTHEW HAHN  HAHN, MATTHEW ABNER MD
# 38104  C00713792               KUNKEL FOR CONGRESS       KUNKEL, CATHERINE
# 38105  C00713792               KUNKEL FOR CONGRESS       KUNKEL, CATHERINE
# 38106  C00759621  BELINDA FOX-SPENCER FOR CONGRESS    FOX-SPENCER, BELINDA
# 38107  C00718858        HILARY TURNER FOR CONGRESS          TURNER, HILARY
#
#        cand_election_yr cand_office cand_office_st cand_pty_affiliation  \
# 38103              2020           H             WV                  REP
# 38104              2020           H             WV                  DEM
# 38105              2020           H             WV                  DEM
# 38106              2020           H             WV                  IND
# 38107              2020           H             WV                  DEM
#
#       cmte_st cmte_pty_affiliation    cand_id  transaction_amt transaction_dt  \
# ...

# %%
df_test.dtypes
# Out:
# cmte_id                  object
# cmte_nm                  object
# cand_name                object
# cmte_st                  object
# cmte_pty_affiliation     object
# cand_id                  object
# transaction_amt         float64
# transaction_dt           object
# category                 object
# category_desc            object
# state                    object
# dtype: object

# %%
df_test.shape
# Out:
# (38108, 11)

# %%
df_test['transaction_amt'].hist()
# Out:
# <AxesSubplot:>

# %%
df_test.describe()
# Out:
#        transaction_amt
# count     38108.000000
# mean       5179.529570
# std       25904.588451
# min      -24783.030000
# 25%         145.000000
# 50%         500.000000
# 75%        1671.297500
# max      817000.000000

# %%
df_test.isnull().any()
# Out:
# cmte_id                 False
# cmte_nm                 False
# cand_name               False
# cmte_st                 False
# cmte_pty_affiliation     True
# cand_id                 False
# transaction_amt         False
# transaction_dt          False
# category                False
# category_desc            True
# state                    True
# dtype: bool

# %%
df_test.isna().sum()
# Out:
# cmte_id                   0
# cmte_nm                   0
# cand_name                 0
# cmte_st                   0
# cmte_pty_affiliation     81
# cand_id                   0
# transaction_amt           0
# transaction_dt            0
# category                  0
# category_desc           104
# state                   410
# dtype: int64

# %% [markdown]
# ## Using Final FEC dataset

# %%
fec = pd.read_csv("all_fec.csv")
# Out:
# /usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
fec.head()
# Out:
#    Unnamed: 0 state    cmte_id category month-year  file_name_year  \
# 0           0    AK  C00261370      002    2004-07            2004
# 1           1    AZ  C00261370      001    2003-01            2004
# 2           2    AZ  C00261370      001    2003-02            2004
# 3           3    AZ  C00261370      001    2003-03            2004
# 4           4    AZ  C00261370      001    2003-04            2004
#
#    transaction_amt  year                     cmte_nm cmte_st  ...  \
# 0           547.80  2004  RICHARD POMBO FOR CONGRESS      CA  ...
# 1          1276.56  2003  RICHARD POMBO FOR CONGRESS      CA  ...
# 2            71.80  2003  RICHARD POMBO FOR CONGRESS      CA  ...
# 3           511.62  2003  RICHARD POMBO FOR CONGRESS      CA  ...
# 4           481.69  2003  RICHARD POMBO FOR CONGRESS      CA  ...
#
#   fec_election_yr cmte_tp_y cand_election_yr_y      cand_name  \
# 0            2004         H               2004  POMBO RICHARD
# ...

# %%
fec.dtypes
# Out:
# Unnamed: 0                int64
# state                    object
# cmte_id                  object
# category                 object
# month-year               object
# file_name_year            int64
# transaction_amt         float64
# year                      int64
# cmte_nm                  object
# cmte_st                  object
# cmte_pty_affiliation     object
# cand_id                  object
# cmte_tp_x                object
# cand_election_yr_x        int64
# fec_election_yr           int64
# cmte_tp_y                object
# cand_election_yr_y        int64
# cand_name                object
# cand_pty_affiliation     object
# cand_office_st           object
# cand_office              object
# cand_pcc                 object
# cand_status              object
# cand_ici                 object
# dtype: object

# %%
fec = fec.drop(["Unnamed: 0"], axis=1)

# %%
fec.columns
# Out:
# Index(['state', 'cmte_id', 'category', 'month-year', 'file_name_year',
#        'transaction_amt', 'year', 'cmte_nm', 'cmte_st', 'cmte_pty_affiliation',
#        'cand_id', 'cmte_tp_x', 'cand_election_yr_x', 'fec_election_yr',
#        'cmte_tp_y', 'cand_election_yr_y', 'cand_name', 'cand_pty_affiliation',
#        'cand_office_st', 'cand_office', 'cand_pcc', 'cand_status', 'cand_ici'],
#       dtype='object')

# %%
fec[['month-year-ds', 'year', 'cand_election_yr_x', 'fec_election_yr', 'cand_election_yr_y']]
# Out:
#        month-year  year  cand_election_yr_x  fec_election_yr  \
# 0         2004-07  2004                2004             2004
# 1         2003-01  2003                2004             2004
# 2         2003-02  2003                2004             2004
# 3         2003-03  2003                2004             2004
# 4         2003-04  2003                2004             2004
# ...           ...   ...                 ...              ...
# 843474    2016-06  2016                2016             2016
# 843475    2016-07  2016                2016             2016
# 843476    2016-07  2016                2016             2016
# 843477    2016-10  2016                2016             2016
# 843478    2016-10  2016                2016             2016
#
#         cand_election_yr_y
# 0                     2004
# 1                     2004
# 2                     2004
# 3                     2004
# 4                     2004
# ...                    ...
# 843474                2016
# ...

# %%
fec['month-year-ds'] = pd.to_datetime(fec['month-year'], format= '%Y-%m-%d', errors = 'coerce')
fec['cand_election_yr_y_ds'] = pd.to_datetime(fec['cand_election_yr_y'], format= '%Y-%m-%d', errors = 'coerce')
fec['cand_election_yr_x_ds'] = pd.to_datetime(fec['cand_election_yr_x'], format= '%Y-%m-%d', errors = 'coerce')
fec['fec_election_yr_ds'] = pd.to_datetime(fec['fec_election_yr'], format= '%Y-%m-%d', errors = 'coerce')
fec['year-ds'] = pd.to_datetime(fec['year'], format= '%Y-%m-%d', errors = 'coerce')

# %%
fec['cand_election_yr_y_ds'] = pd.to_datetime(fec['cand_election_yr_y'], format= '%Y')
fec['cand_election_yr_x_ds'] = pd.to_datetime(fec['cand_election_yr_x'], format= '%Y')
fec['fec_election_yr_ds'] = pd.to_datetime(fec['fec_election_yr'], format= '%Y')
fec['year-ds'] = pd.to_datetime(fec['year'], format= '%Y')

# %%
fec.head()
# Out:
#   state    cmte_id category month-year  file_name_year  transaction_amt  year  \
# 0    AK  C00261370      002    2004-07            2004           547.80  2004
# 1    AZ  C00261370      001    2003-01            2004          1276.56  2003
# 2    AZ  C00261370      001    2003-02            2004            71.80  2003
# 3    AZ  C00261370      001    2003-03            2004           511.62  2003
# 4    AZ  C00261370      001    2003-04            2004           481.69  2003
#
#                       cmte_nm cmte_st cmte_pty_affiliation  ...  \
# 0  RICHARD POMBO FOR CONGRESS      CA                  REP  ...
# 1  RICHARD POMBO FOR CONGRESS      CA                  REP  ...
# 2  RICHARD POMBO FOR CONGRESS      CA                  REP  ...
# 3  RICHARD POMBO FOR CONGRESS      CA                  REP  ...
# 4  RICHARD POMBO FOR CONGRESS      CA                  REP  ...
#
#   cand_office_st cand_office   cand_pcc  cand_status cand_ici  month-year-ds  \
# ...

# %%
fec.to_csv("all_fec.csv", index = False)

# %%
fec.columns
# Out:
# Index(['state', 'cmte_id', 'category', 'month-year', 'file_name_year',
#        'transaction_amt', 'year', 'cmte_nm', 'cmte_st', 'cmte_pty_affiliation',
#        'cand_id', 'cmte_tp_x', 'cand_election_yr_x', 'fec_election_yr',
#        'cmte_tp_y', 'cand_election_yr_y', 'cand_name', 'cand_pty_affiliation',
#        'cand_office_st', 'cand_office', 'cand_pcc', 'cand_status', 'cand_ici',
#        'month-year-ds', 'cand_election_yr_y_ds', 'cand_election_yr_x_ds',
#        'fec_election_yr_ds', 'year-ds'],
#       dtype='object')

# %%
fec_ds = fec.drop(['cmte_tp_y','cand_election_yr_y', 'cand_election_yr_x', 'fec_election_yr','cmte_tp_x', 'month-year', 'year', 'file_name_year','cand_election_yr_x_ds'], axis = 1)

# %%
fec_ds_pre = fec_ds.loc[fec_ds['cand_office'].isin(['P'])]

# %%
fec_ds_house = fec_ds.loc[fec_ds['cand_office'].isin(['H'])]

# %%
fec_ds_senate = fec_ds.loc[fec_ds['cand_office'].isin(['S'])]

# %%
fec_ds_house['cand_office'].unique()
# Out:
# array(['H'], dtype=object)

# %%
fec_ds_house.to_csv("all_fec_ds_house.csv", index = False)

# %%
fec_ds_senate.to_csv("all_fec_ds_senate.csv", index = False)

# %%
fec_ds_pre['cand_ici'].unique()
# Out:
# array(['C', 'I', 'O', nan], dtype=object)

# %%
fec_ds_pre.loc[fec_ds_pre['cand_ici'].isin(['C'])]
